# %%
import geopandas as gpd
gpd.__version__
# Out:
# '0.10.2'

# %%
import matplotlib.pyplot as plt

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ls -a
# Out:
# ./                          MEDSTAT_AREAS_2019.prj
# ../                         MEDSTAT_AREAS_2019.shp
# .ipynb_checkpoints/         MEDSTAT_AREAS_2019.shx
# MEDSTAT-PTS-2019.dbf        MEDSTAT_AREAS_2019.xml
# MEDSTAT-PTS-2019.prj        Shape-Copy1.ipynb
# MEDSTAT-PTS-2019.shp        image.jpg
# MEDSTAT-PTS-2019.shx        map.py
# MEDSTAT-PTS-2019.xml        medstat in Switzerland.png
# MEDSTAT_AREAS_2019.dbf      myfigure.jpeg

# %%
geo_data = gpd.read_file('MEDSTAT_AREAS_2019.shp', encoding='cp949', tiles='None')

# %%
center = [46.8182,8.2275]

# %%
import folium

# %%
g_map = folium.Map(location = center, zoom_start = 7)

# %%
geo_data
# Out:
#       MDSTID                 MDSTNAME MDST04 MDSTKT  MDSTNUM  \
# 0    ZH00101               Zrich-City   ZH01     ZH        1
# 1    ZH00102           Zrich-Sihlfeld   ZH02     ZH        2
# 2    ZH00103         Zrich-Aussersihl   ZH03     ZH        3
# 3    ZH00104      Zrich-Industriequar   ZH04     ZH        4
# 4    ZH00105         Zrich-Universitt   ZH05     ZH        5
# ..       ...                      ...    ...    ...      ...
# 701  JU10605  Clos-du-Doubs-Courgenay   JU05     JU      702
# 702  JU10606               Porrentruy   JU06     JU      703
# 703  JU10607    Basse-Allaine-Damvant   JU07     JU      704
# 704  JU10608     Haute-Allaine-Bonfol   JU08     JU      705
# 705  FL10700  Frstentum Liechtenstein   FL00     FL      706
#
#                                               geometry
# 0    POLYGON ((681389.682 244890.546, 681410.278 24...
# 1    POLYGON ((680092.573 248011.812, 680104.690 24...
# 2    POLYGON ((680403.391 248403.521, 680418.725 24...
# ...

# %%
marker_GE = folium.Marker ([46.204391, 6.143158],
                       popup='Geneva',
                       icon=folium.Icon(color='blue'))
marker_GE.add_to(g_map)

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
marker_LS = folium.Marker ([46.519962, 6.633597],
                       popup='Lausanne',
                       icon=folium.Icon(color='blue'))
marker_LS.add_to(g_map)

# %%
marker_BS = folium.Marker ([47.559601, 7.588576],
                       popup='Basel',
                       icon=folium.Icon(color='blue'))
marker_BS.add_to(g_map)

# %%
marker_LZ = folium.Marker ([47.05048, 8.30635],
                       popup='Luzern',
                       icon=folium.Icon(color='blue'))
marker_LZ.add_to(g_map)

# %%
marker_SG = folium.Marker ([47.42391, 9.37477],
                       popup='St. Gallen',
                       icon=folium.Icon(color='blue'))
marker_SG.add_to(g_map)

# %%
marker_ZH = folium.Marker ([47.36667, 8.55],
                       popup='Zurich',
                       icon=folium.Icon(color='blue'))
marker_ZH.add_to(g_map)

# %%
marker_LG = folium.Marker ([46.01008, 8.96004],
                       popup='Lugano',
                       icon=folium.Icon(color='blue'))
marker_LG.add_to(g_map)

# %%
marker_BE = folium.Marker ([46.94809, 7.44744],
                       popup='Bern',
                       icon=folium.Icon(color='blue'))
marker_BE.add_to(g_map)

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
ax = geo_data.convex_hull.plot(color='skyblue', edgecolor="w")
ax.set_title("MEDSTAT regions in Switzerland")
ax.set_axis_off()

# %%
ax = geo_data.plot()
ax.set_title("MEDSTAT regions in Switzerland")
ax.set_axis_off()
plt.savefig('medstat in Switzerland.png')
